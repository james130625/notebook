# %% [markdown]
# <a href="https://colab.research.google.com/github/james130625/notebook/blob/main/13_NASDAQ_%EC%B5%9C%EC%A2%85.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 필요한 패키지 설치
# !apt-get install -y fonts-nanum
# !fc-cache -fv
# !rm -rf ~/.cache/matplotlib

# FinanceDataReader 설치
# !pip install finance-datareader

# matplotlib, pandas 임포트 및 주피터 출력 설정, 한글 폰트 지정
import matplotlib.pyplot as plt
import FinanceDataReader as fdr
import pandas as pd
import numpy as np
from datetime import datetime

plt.rcParams['font.family'] = 'NanumBarunGothic'  # 한글 출력을 위한 폰트 설정

# NASDAQ 상장 목록 가져오기
nasdaq_list = fdr.StockListing('NASDAQ')

# 데이터프레임의 열 이름 확인
print(nasdaq_list.columns)

# 열 이름 확인 후 'Symbol' 열 사용
symbol_column_name = 'Symbol'
close_column_name = 'Close'

# 필터링 조건
price_lower = 5
price_upper = 10

# 필터링된 데이터프레임 저장용 리스트
filtered_stocks_data = []

# 오늘 날짜 구하기
today = datetime.today().strftime('%Y-%m-%d')

# 각 종목의 데이터를 가져와서 조건에 맞는지 확인 및 상태 식별
for symbol in nasdaq_list[symbol_column_name]:
    try:
        # 종목 데이터 불러오기 (2023-01-02부터 오늘까지)
        data = fdr.DataReader(symbol, '2023-01-02', today)

        # 종가가 5-10 달러 사이에 있는지 확인
        if data[close_column_name].iloc[-1] < price_lower or data[close_column_name].iloc[-1] > price_upper:
            continue

        # 이동 평균 계산
        data['SMA20'] = data[close_column_name].rolling(window=20).mean()
        data['SMA50'] = data[close_column_name].rolling(window=50).mean()
        data['SMA200'] = data[close_column_name].rolling(window=200).mean()

        # 거래량 평균 계산
        avg_volume = data['Volume'].mean()

        # 변동폭 계산 (종가의 표준편차)
        volatility = data[close_column_name].std()

        # MACD 및 시그널 계산
        exp1 = data[close_column_name].ewm(span=12, adjust=False).mean()
        exp2 = data[close_column_name].ewm(span=26, adjust=False).mean()
        macd = exp1 - exp2
        signal = macd.ewm(span=9, adjust=False).mean()

        # 가장 최근 종가
        recent_close = data[close_column_name].iloc[-1]

        # 추세 계산
        trend = 'Uptrend' if macd.iloc[-1] > signal.iloc[-1] else 'Downtrend'

        # 매수가 범위 계산 (±2%)
        buy_range_low = recent_close * 0.98
        buy_range_high = recent_close * 1.02

        # 1차, 2차, 3차 매수가
        first_buy = buy_range_low
        second_buy = (buy_range_low + buy_range_high) / 2
        third_buy = buy_range_high

        # 익절가 (최근 종가의 +10%)
        take_profit = recent_close * 1.10

        # 손절가 (최근 종가의 -5%)
        stop_loss = recent_close * 0.95

        # 상태 식별
        data['Phase'] = 'Sleeping'
        conditions = [
            (data['SMA20'] > data['SMA50']) & (data['SMA50'] > data['SMA200']),
            (data['SMA20'] > data['SMA50']) & (data['SMA50'] < data['SMA200']),
        ]
        choices = ['Eating', 'Awakening']
        data['Phase'] = np.select(conditions, choices, default='Sleeping')

        # 조건 필터링
        if macd.iloc[-1] > signal.iloc[-1]:  # MACD 매수 시그널
            filtered_stocks_data.append({
                'Symbol': symbol,
                'Current Price': recent_close,
                'Recent Close': recent_close,
                'Trend': trend,
                'Buy Range': f"{buy_range_low:.2f} - {buy_range_high:.2f}",
                'First Buy': first_buy,
                'Second Buy': second_buy,
                'Third Buy': third_buy,
                'Take Profit': take_profit,
                'Stop Loss': stop_loss,
                'Avg Volume': avg_volume,
                'Volatility': volatility,
                'Phase': data['Phase'].iloc[-1]
            })
    except Exception as e:
        # 데이터 불러오기에 실패하면 무시
        print(f"Failed to process {symbol}: {e}")
        continue

# 필터링된 종목 데이터프레임 생성 및 정렬
filtered_stocks_df = pd.DataFrame(filtered_stocks_data)

# 거래량이 많고 변동폭이 낮은 순으로 정렬
filtered_stocks_df = filtered_stocks_df.sort_values(by=['Avg Volume', 'Volatility'], ascending=[False, True])

# 상위 10개 종목 선정
top_10_stocks_df = filtered_stocks_df.head(10)

# 결과 출력
print("조건에 맞는 상위 10개 종목 목록:")
print(top_10_stocks_df)

# 필터링된 종목 리스트 데이터프레임 출력 함수
def display_dataframe_to_user(name: str, dataframe: pd.DataFrame) -> None:
    from IPython.display import display, HTML
    display(HTML(f"<h2>{name}</h2>"))
    display(dataframe)

display_dataframe_to_user(name="조건에 맞는 상위 10개 NASDAQ 종목 목록", dataframe=top_10_stocks_df)
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 45 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 2s (5,612 kB/s)
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 121913 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20200506-1_all.deb ...
# Unpacking fonts-nanum (20200506-1) ...
# Setting up fonts-nanum (20200506-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# /usr/share/fonts/truetype/nanum: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded
# Collecting finance-datareader
#   Downloading finance_datareader-0.9.90-py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.6/46.6 kB 1.0 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=0.19.2 in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (2.0.3)
# Requirement already satisfied: requests>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (2.31.0)
# Collecting requests-file (from finance-datareader)
#   Downloading requests_file-2.1.0-py2.py3-none-any.whl (4.2 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (4.9.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (4.66.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19.2->finance-datareader) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19.2->finance-datareader) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19.2->finance-datareader) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19.2->finance-datareader) (1.25.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (2024.6.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=0.19.2->finance-datareader) (1.16.0)
# Installing collected packages: requests-file, finance-datareader
# Successfully installed finance-datareader-0.9.90 requests-file-2.1.0
# 100%|██████████| 3765/3765 [00:19<00:00, 192.90it/s]
# Index(['Symbol', 'Name', 'IndustryCode', 'Industry'], dtype='object')
# HTTP Error 404: Not Found  - symbol "GWACU" not found or invalid periods
# Failed to process GWACU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CGEN" not found or invalid periods
# Failed to process CGEN: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ITI" not found or invalid periods
# Failed to process ITI: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SANG" not found or invalid periods
# Failed to process SANG: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "GLSI" not found or invalid periods
# Failed to process GLSI: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CLLS" not found or invalid periods
# Failed to process CLLS: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BAER" not found or invalid periods
# Failed to process BAER: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "FFNW" not found or invalid periods
# Failed to process FFNW: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BPRN" not found or invalid periods
# Failed to process BPRN: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ZEO" not found or invalid periods
# Failed to process ZEO: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "PNRG" not found or invalid periods
# Failed to process PNRG: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "FITBP" not found or invalid periods
# Failed to process FITBP: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CRBU" not found or invalid periods
# Failed to process CRBU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "PKBK" not found or invalid periods
# Failed to process PKBK: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "NPCE" not found or invalid periods
# Failed to process NPCE: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "TLSI" not found or invalid periods
# Failed to process TLSI: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "NBSTU" not found or invalid periods
# Failed to process NBSTU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "FENC" not found or invalid periods
# Failed to process FENC: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BRLS" not found or invalid periods
# Failed to process BRLS: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CVGI" not found or invalid periods
# Failed to process CVGI: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "LWAY" not found or invalid periods
# Failed to process LWAY: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "HFFG" not found or invalid periods
# Failed to process HFFG: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ESCA" not found or invalid periods
# Failed to process ESCA: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SNFCA" not found or invalid periods
# Failed to process SNFCA: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "DCTH" not found or invalid periods
# Failed to process DCTH: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SSTI" not found or invalid periods
# Failed to process SSTI: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "LFCR" not found or invalid periods
# Failed to process LFCR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "IVA" not found or invalid periods
# Failed to process IVA: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "WAFDP" not found or invalid periods
# Failed to process WAFDP: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "MOND" not found or invalid periods
# Failed to process MOND: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "IVCA" not found or invalid periods
# Failed to process IVCA: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "KNDI" not found or invalid periods
# Failed to process KNDI: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "OXSQ" not found or invalid periods
# Failed to process OXSQ: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ATLO" not found or invalid periods
# Failed to process ATLO: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SEVN" not found or invalid periods
# Failed to process SEVN: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ACHV" not found or invalid periods
# Failed to process ACHV: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SEPAU" not found or invalid periods
# Failed to process SEPAU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "PTMN" not found or invalid periods
# Failed to process PTMN: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "HQI" not found or invalid periods
# Failed to process HQI: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ULBI" not found or invalid periods
# Failed to process ULBI: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "FLXS" not found or invalid periods
# Failed to process FLXS: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "FCNCO" not found or invalid periods
# Failed to process FCNCO: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SHMD" not found or invalid periods
# Failed to process SHMD: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "RGTI" not found or invalid periods
# Failed to process RGTI: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "LVO" not found or invalid periods
# Failed to process LVO: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CMPX" not found or invalid periods
# Failed to process CMPX: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "PVBC" not found or invalid periods
# Failed to process PVBC: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ARAY" not found or invalid periods
# Failed to process ARAY: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "OCAXU" not found or invalid periods
# Failed to process OCAXU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "QRHC" not found or invalid periods
# Failed to process QRHC: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "DRTS" not found or invalid periods
# Failed to process DRTS: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CALB" not found or invalid periods
# Failed to process CALB: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "FTEL" not found or invalid periods
# Failed to process FTEL: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "VIRC" not found or invalid periods
# Failed to process VIRC: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "INMB" not found or invalid periods
# Failed to process INMB: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BELFA" not found or invalid periods
# Failed to process BELFA: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "EGAN" not found or invalid periods
# Failed to process EGAN: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "AACIU" not found or invalid periods
# Failed to process AACIU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "MSSAU" not found or invalid periods
# Failed to process MSSAU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ABEO" not found or invalid periods
# Failed to process ABEO: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "DTI" not found or invalid periods
# Failed to process DTI: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "EML" not found or invalid periods
# Failed to process EML: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SMID" not found or invalid periods
# Failed to process SMID: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "HCVI" not found or invalid periods
# Failed to process HCVI: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "NYMTM" not found or invalid periods
# Failed to process NYMTM: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "FLL" not found or invalid periods
# Failed to process FLL: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CPSS" not found or invalid periods
# Failed to process CPSS: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "DOGZ" not found or invalid periods
# Failed to process DOGZ: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "QUIK" not found or invalid periods
# Failed to process QUIK: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "FANH" not found or invalid periods
# Failed to process FANH: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CAPR" not found or invalid periods
# Failed to process CAPR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BLUE" not found or invalid periods
# Failed to process BLUE: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "TRVI" not found or invalid periods
# Failed to process TRVI: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "NTIC" not found or invalid periods
# Failed to process NTIC: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "STHO" not found or invalid periods
# Failed to process STHO: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "PIII" not found or invalid periods
# Failed to process PIII: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "NKSH" not found or invalid periods
# Failed to process NKSH: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "OGI" not found or invalid periods
# Failed to process OGI: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "TUSK" not found or invalid periods
# Failed to process TUSK: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "PBYI" not found or invalid periods
# Failed to process PBYI: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ESSA" not found or invalid periods
# Failed to process ESSA: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "XFOR" not found or invalid periods
# Failed to process XFOR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "LBRDP" not found or invalid periods
# Failed to process LBRDP: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CRDL" not found or invalid periods
# Failed to process CRDL: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SPKL" not found or invalid periods
# Failed to process SPKL: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SKGR" not found or invalid periods
# Failed to process SKGR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "VERY" not found or invalid periods
# Failed to process VERY: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "APPS" not found or invalid periods
# Failed to process APPS: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "RPTX" not found or invalid periods
# Failed to process RPTX: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BRKH" not found or invalid periods
# Failed to process BRKH: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "MBCN" not found or invalid periods
# Failed to process MBCN: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "RIGL" not found or invalid periods
# Failed to process RIGL: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "DLHC" not found or invalid periods
# Failed to process DLHC: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "MRCC" not found or invalid periods
# Failed to process MRCC: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "TROO" not found or invalid periods
# Failed to process TROO: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BCBP" not found or invalid periods
# Failed to process BCBP: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "MYFW" not found or invalid periods
# Failed to process MYFW: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "MITAU" not found or invalid periods
# Failed to process MITAU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "STKS" not found or invalid periods
# Failed to process STKS: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "INVZ" not found or invalid periods
# Failed to process INVZ: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CLOEU" not found or invalid periods
# Failed to process CLOEU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "OTLK" not found or invalid periods
# Failed to process OTLK: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "GALT" not found or invalid periods
# Failed to process GALT: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "MCAA" not found or invalid periods
# Failed to process MCAA: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "WAVSU" not found or invalid periods
# Failed to process WAVSU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "VABK" not found or invalid periods
# Failed to process VABK: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "STI" not found or invalid periods
# Failed to process STI: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SIFY" not found or invalid periods
# Failed to process SIFY: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "HOFT" not found or invalid periods
# Failed to process HOFT: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "HMST" not found or invalid periods
# Failed to process HMST: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "LAKE" not found or invalid periods
# Failed to process LAKE: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "XTKG" not found or invalid periods
# Failed to process XTKG: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "PROP" not found or invalid periods
# Failed to process PROP: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "FNGR" not found or invalid periods
# Failed to process FNGR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "PRQR" not found or invalid periods
# Failed to process PRQR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "LATGU" not found or invalid periods
# Failed to process LATGU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "VIGL" not found or invalid periods
# Failed to process VIGL: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BCG" not found or invalid periods
# Failed to process BCG: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ALCY" not found or invalid periods
# Failed to process ALCY: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ZENV" not found or invalid periods
# Failed to process ZENV: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "AXTI" not found or invalid periods
# Failed to process AXTI: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ATOS" not found or invalid periods
# Failed to process ATOS: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "RELL" not found or invalid periods
# Failed to process RELL: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SUUN" not found or invalid periods
# Failed to process SUUN: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "IHRT" not found or invalid periods
# Failed to process IHRT: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SCWO" not found or invalid periods
# Failed to process SCWO: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CRVO" not found or invalid periods
# Failed to process CRVO: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "PEBK" not found or invalid periods
# Failed to process PEBK: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "PESI" not found or invalid periods
# Failed to process PESI: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ANL" not found or invalid periods
# Failed to process ANL: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "KOD" not found or invalid periods
# Failed to process KOD: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "TRVG" not found or invalid periods
# Failed to process TRVG: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "THCH" not found or invalid periods
# Failed to process THCH: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CLPT" not found or invalid periods
# Failed to process CLPT: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "GRWG" not found or invalid periods
# Failed to process GRWG: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BZUN" not found or invalid periods
# Failed to process BZUN: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "MDWD" not found or invalid periods
# Failed to process MDWD: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CBAT" not found or invalid periods
# Failed to process CBAT: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "AENT" not found or invalid periods
# Failed to process AENT: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "NIU" not found or invalid periods
# Failed to process NIU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "GTHX" not found or invalid periods
# Failed to process GTHX: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ADVM" not found or invalid periods
# Failed to process ADVM: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "EMLD" not found or invalid periods
# Failed to process EMLD: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "UEIC" not found or invalid periods
# Failed to process UEIC: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ORGN" not found or invalid periods
# Failed to process ORGN: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "LSB" not found or invalid periods
# Failed to process LSB: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "FULTP" not found or invalid periods
# Failed to process FULTP: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "HBANM" not found or invalid periods
# Failed to process HBANM: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ALCYU" not found or invalid periods
# Failed to process ALCYU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "RDCM" not found or invalid periods
# Failed to process RDCM: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "TELO" not found or invalid periods
# Failed to process TELO: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "PWOD" not found or invalid periods
# Failed to process PWOD: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ALIM" not found or invalid periods
# Failed to process ALIM: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ESHA" not found or invalid periods
# Failed to process ESHA: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "III" not found or invalid periods
# Failed to process III: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "GEVO" not found or invalid periods
# Failed to process GEVO: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "HOWL" not found or invalid periods
# Failed to process HOWL: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "EHTH" not found or invalid periods
# Failed to process EHTH: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ISTR" not found or invalid periods
# Failed to process ISTR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "RCMT" not found or invalid periods
# Failed to process RCMT: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CFFI" not found or invalid periods
# Failed to process CFFI: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "IMAB" not found or invalid periods
# Failed to process IMAB: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "OPTN" not found or invalid periods
# Failed to process OPTN: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "MAPS" not found or invalid periods
# Failed to process MAPS: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "NNBR" not found or invalid periods
# Failed to process NNBR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ABOS" not found or invalid periods
# Failed to process ABOS: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BDSX" not found or invalid periods
# Failed to process BDSX: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "TAYD" not found or invalid periods
# Failed to process TAYD: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SGMT" not found or invalid periods
# Failed to process SGMT: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "TVGN" not found or invalid periods
# Failed to process TVGN: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "WSBCP" not found or invalid periods
# Failed to process WSBCP: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SIGIP" not found or invalid periods
# Failed to process SIGIP: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "MAMO" not found or invalid periods
# Failed to process MAMO: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "TATT" not found or invalid periods
# Failed to process TATT: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "TBRG" not found or invalid periods
# Failed to process TBRG: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "QXO" not found or invalid periods
# Failed to process QXO: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "RGLS" not found or invalid periods
# Failed to process RGLS: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "OPBK" not found or invalid periods
# Failed to process OPBK: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "AMLI" not found or invalid periods
# Failed to process AMLI: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "GOEV" not found or invalid periods
# Failed to process GOEV: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BNAI" not found or invalid periods
# Failed to process BNAI: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "AGNCL" not found or invalid periods
# Failed to process AGNCL: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BPYPN" not found or invalid periods
# Failed to process BPYPN: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "VGAS" not found or invalid periods
# Failed to process VGAS: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "LTRX" not found or invalid periods
# Failed to process LTRX: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ISRLU" not found or invalid periods
# Failed to process ISRLU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "GLLIU" not found or invalid periods
# Failed to process GLLIU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "TETEU" not found or invalid periods
# Failed to process TETEU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BCSA" not found or invalid periods
# Failed to process BCSA: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "EOSE" not found or invalid periods
# Failed to process EOSE: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CCTSU" not found or invalid periods
# Failed to process CCTSU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "WNEB" not found or invalid periods
# Failed to process WNEB: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SYRS" not found or invalid periods
# Failed to process SYRS: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "VXRT" not found or invalid periods
# Failed to process VXRT: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "TELA" not found or invalid periods
# Failed to process TELA: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "PEGR" not found or invalid periods
# Failed to process PEGR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ISRL" not found or invalid periods
# Failed to process ISRL: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "MOLN" not found or invalid periods
# Failed to process MOLN: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ZIONO" not found or invalid periods
# Failed to process ZIONO: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "PLCE" not found or invalid periods
# Failed to process PLCE: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "RAPT" not found or invalid periods
# Failed to process RAPT: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "AMTX" not found or invalid periods
# Failed to process AMTX: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ARBE" not found or invalid periods
# Failed to process ARBE: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SCPH" not found or invalid periods
# Failed to process SCPH: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BRAG" not found or invalid periods
# Failed to process BRAG: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "RRGB" not found or invalid periods
# Failed to process RRGB: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CSPI" not found or invalid periods
# Failed to process CSPI: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "FTLF" not found or invalid periods
# Failed to process FTLF: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "QIPT" not found or invalid periods
# Failed to process QIPT: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "IBAC" not found or invalid periods
# Failed to process IBAC: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "FEXDU" not found or invalid periods
# Failed to process FEXDU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BPYPO" not found or invalid periods
# Failed to process BPYPO: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "REKR" not found or invalid periods
# Failed to process REKR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "HWBK" not found or invalid periods
# Failed to process HWBK: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "GOSS" not found or invalid periods
# Failed to process GOSS: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "LOGC" not found or invalid periods
# Failed to process LOGC: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "VERU" not found or invalid periods
# Failed to process VERU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "GMFIU" not found or invalid periods
# Failed to process GMFIU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "VMCA" not found or invalid periods
# Failed to process VMCA: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "MBINM" not found or invalid periods
# Failed to process MBINM: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "LGO" not found or invalid periods
# Failed to process LGO: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "NYMTN" not found or invalid periods
# Failed to process NYMTN: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "FTIIU" not found or invalid periods
# Failed to process FTIIU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CRDF" not found or invalid periods
# Failed to process CRDF: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "FUNC" not found or invalid periods
# Failed to process FUNC: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "AFBI" not found or invalid periods
# Failed to process AFBI: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ADAG" not found or invalid periods
# Failed to process ADAG: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ALOT" not found or invalid periods
# Failed to process ALOT: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "GEOS" not found or invalid periods
# Failed to process GEOS: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "OFS" not found or invalid periods
# Failed to process OFS: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ZLS" not found or invalid periods
# Failed to process ZLS: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "MACAU" not found or invalid periods
# Failed to process MACAU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CRVS" not found or invalid periods
# Failed to process CRVS: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CNTX" not found or invalid periods
# Failed to process CNTX: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "TOUR" not found or invalid periods
# Failed to process TOUR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "FGBI" not found or invalid periods
# Failed to process FGBI: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BANX" not found or invalid periods
# Failed to process BANX: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ALSAU" not found or invalid periods
# Failed to process ALSAU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "WILC" not found or invalid periods
# Failed to process WILC: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CTMX" not found or invalid periods
# Failed to process CTMX: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "WW" not found or invalid periods
# Failed to process WW: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "DLTH" not found or invalid periods
# Failed to process DLTH: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "HBIO" not found or invalid periods
# Failed to process HBIO: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BSET" not found or invalid periods
# Failed to process BSET: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "FINW" not found or invalid periods
# Failed to process FINW: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "MCRB" not found or invalid periods
# Failed to process MCRB: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "YOTAU" not found or invalid periods
# Failed to process YOTAU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "AHG" not found or invalid periods
# Failed to process AHG: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "MBINN" not found or invalid periods
# Failed to process MBINN: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "RMBI" not found or invalid periods
# Failed to process RMBI: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ATYR" not found or invalid periods
# Failed to process ATYR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "EXFY" not found or invalid periods
# Failed to process EXFY: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "GATE" not found or invalid periods
# Failed to process GATE: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "KGEI" not found or invalid periods
# Failed to process KGEI: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "MNSB" not found or invalid periods
# Failed to process MNSB: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BVFL" not found or invalid periods
# Failed to process BVFL: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "MMLP" not found or invalid periods
# Failed to process MMLP: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "WINVU" not found or invalid periods
# Failed to process WINVU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "COOL" not found or invalid periods
# Failed to process COOL: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "PRPL" not found or invalid periods
# Failed to process PRPL: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "AFARU" not found or invalid periods
# Failed to process AFARU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CRNC" not found or invalid periods
# Failed to process CRNC: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "FCCO" not found or invalid periods
# Failed to process FCCO: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "MRAM" not found or invalid periods
# Failed to process MRAM: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "UBFO" not found or invalid periods
# Failed to process UBFO: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "MBINO" not found or invalid periods
# Failed to process MBINO: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "EVGR" not found or invalid periods
# Failed to process EVGR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "LANDO" not found or invalid periods
# Failed to process LANDO: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CFBK" not found or invalid periods
# Failed to process CFBK: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "FTAIO" not found or invalid periods
# Failed to process FTAIO: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "IGTAU" not found or invalid periods
# Failed to process IGTAU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "INTEU" not found or invalid periods
# Failed to process INTEU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "KLTR" not found or invalid periods
# Failed to process KLTR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "XNET" not found or invalid periods
# Failed to process XNET: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "WTFCM" not found or invalid periods
# Failed to process WTFCM: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ONBPO" not found or invalid periods
# Failed to process ONBPO: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BFIN" not found or invalid periods
# Failed to process BFIN: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ESOA" not found or invalid periods
# Failed to process ESOA: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SGMO" not found or invalid periods
# Failed to process SGMO: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BTM" not found or invalid periods
# Failed to process BTM: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SY" not found or invalid periods
# Failed to process SY: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SCTL" not found or invalid periods
# Failed to process SCTL: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SPWH" not found or invalid periods
# Failed to process SPWH: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "OCCI" not found or invalid periods
# Failed to process OCCI: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "TWLV" not found or invalid periods
# Failed to process TWLV: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "AVHIU" not found or invalid periods
# Failed to process AVHIU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "PLMI" not found or invalid periods
# Failed to process PLMI: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ROCLU" not found or invalid periods
# Failed to process ROCLU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "NVCT" not found or invalid periods
# Failed to process NVCT: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "RFAIU" not found or invalid periods
# Failed to process RFAIU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "AMLX" not found or invalid periods
# Failed to process AMLX: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "LUNA" not found or invalid periods
# Failed to process LUNA: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "FGEN" not found or invalid periods
# Failed to process FGEN: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "HNVR" not found or invalid periods
# Failed to process HNVR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "EVGRU" not found or invalid periods
# Failed to process EVGRU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CAAS" not found or invalid periods
# Failed to process CAAS: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CBFV" not found or invalid periods
# Failed to process CBFV: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BRACU" not found or invalid periods
# Failed to process BRACU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "LOOP" not found or invalid periods
# Failed to process LOOP: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "FEBO" not found or invalid periods
# Failed to process FEBO: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "MVST" not found or invalid periods
# Failed to process MVST: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CZWI" not found or invalid periods
# Failed to process CZWI: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "EPSN" not found or invalid periods
# Failed to process EPSN: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "FLYE" not found or invalid periods
# Failed to process FLYE: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "HURC" not found or invalid periods
# Failed to process HURC: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "MRBK" not found or invalid periods
# Failed to process MRBK: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "VFF" not found or invalid periods
# Failed to process VFF: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "FRAF" not found or invalid periods
# Failed to process FRAF: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "HTLFP" not found or invalid periods
# Failed to process HTLFP: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "GODNU" not found or invalid periods
# Failed to process GODNU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "FATBP" not found or invalid periods
# Failed to process FATBP: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BYNO" not found or invalid periods
# Failed to process BYNO: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ACET" not found or invalid periods
# Failed to process ACET: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "MSBIP" not found or invalid periods
# Failed to process MSBIP: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "APXI" not found or invalid periods
# Failed to process APXI: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "EMCGU" not found or invalid periods
# Failed to process EMCGU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "KPTI" not found or invalid periods
# Failed to process KPTI: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "STRT" not found or invalid periods
# Failed to process STRT: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "VOXR" not found or invalid periods
# Failed to process VOXR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SEER" not found or invalid periods
# Failed to process SEER: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CTXR" not found or invalid periods
# Failed to process CTXR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ECBK" not found or invalid periods
# Failed to process ECBK: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CDAQ" not found or invalid periods
# Failed to process CDAQ: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "YIBO" not found or invalid periods
# Failed to process YIBO: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "HYZN" not found or invalid periods
# Failed to process HYZN: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ISSC" not found or invalid periods
# Failed to process ISSC: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "FSFG" not found or invalid periods
# Failed to process FSFG: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CFFS" not found or invalid periods
# Failed to process CFFS: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "WMPN" not found or invalid periods
# Failed to process WMPN: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "PFTA" not found or invalid periods
# Failed to process PFTA: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "FRLAU" not found or invalid periods
# Failed to process FRLAU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "RILYM" not found or invalid periods
# Failed to process RILYM: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "INCR" not found or invalid periods
# Failed to process INCR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "OMGA" not found or invalid periods
# Failed to process OMGA: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ZTEK" not found or invalid periods
# Failed to process ZTEK: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "AOGOU" not found or invalid periods
# Failed to process AOGOU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ALTO" not found or invalid periods
# Failed to process ALTO: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "IMUX" not found or invalid periods
# Failed to process IMUX: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CITE" not found or invalid periods
# Failed to process CITE: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CPHC" not found or invalid periods
# Failed to process CPHC: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "MYNA" not found or invalid periods
# Failed to process MYNA: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "KEQU" not found or invalid periods
# Failed to process KEQU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "RFACU" not found or invalid periods
# Failed to process RFACU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "UNB" not found or invalid periods
# Failed to process UNB: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "MNTX" not found or invalid periods
# Failed to process MNTX: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "FNCB" not found or invalid periods
# Failed to process FNCB: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SPKLU" not found or invalid periods
# Failed to process SPKLU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "WPRT" not found or invalid periods
# Failed to process WPRT: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "OVBC" not found or invalid periods
# Failed to process OVBC: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "DBVT" not found or invalid periods
# Failed to process DBVT: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ONBPP" not found or invalid periods
# Failed to process ONBPP: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "IMPP" not found or invalid periods
# Failed to process IMPP: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BPYPP" not found or invalid periods
# Failed to process BPYPP: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SFBC" not found or invalid periods
# Failed to process SFBC: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CLRB" not found or invalid periods
# Failed to process CLRB: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "OPRT" not found or invalid periods
# Failed to process OPRT: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BWAY" not found or invalid periods
# Failed to process BWAY: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "TLGY" not found or invalid periods
# Failed to process TLGY: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "REGCP" not found or invalid periods
# Failed to process REGCP: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BROG" not found or invalid periods
# Failed to process BROG: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "GIFI" not found or invalid periods
# Failed to process GIFI: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "POET" not found or invalid periods
# Failed to process POET: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ESGRO" not found or invalid periods
# Failed to process ESGRO: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "LARK" not found or invalid periods
# Failed to process LARK: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "TENKU" not found or invalid periods
# Failed to process TENKU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "FTAIN" not found or invalid periods
# Failed to process FTAIN: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "OPI" not found or invalid periods
# Failed to process OPI: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SERV" not found or invalid periods
# Failed to process SERV: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "THCP" not found or invalid periods
# Failed to process THCP: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "VSACU" not found or invalid periods
# Failed to process VSACU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "FLFVU" not found or invalid periods
# Failed to process FLFVU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "TZOO" not found or invalid periods
# Failed to process TZOO: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "GAIA" not found or invalid periods
# Failed to process GAIA: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "MCAC" not found or invalid periods
# Failed to process MCAC: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ACNT" not found or invalid periods
# Failed to process ACNT: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CSLM" not found or invalid periods
# Failed to process CSLM: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "PDSB" not found or invalid periods
# Failed to process PDSB: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "GPAC" not found or invalid periods
# Failed to process GPAC: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SGA" not found or invalid periods
# Failed to process SGA: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "TGAA" not found or invalid periods
# Failed to process TGAA: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "NNAG" not found or invalid periods
# Failed to process NNAG: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "EBMT" not found or invalid periods
# Failed to process EBMT: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "FNWD" not found or invalid periods
# Failed to process FNWD: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "GSIW" not found or invalid periods
# Failed to process GSIW: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CGO" not found or invalid periods
# Failed to process CGO: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "FTAIP" not found or invalid periods
# Failed to process FTAIP: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "KRMD" not found or invalid periods
# Failed to process KRMD: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ELDN" not found or invalid periods
# Failed to process ELDN: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "VLYPP" not found or invalid periods
# Failed to process VLYPP: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "MFH" not found or invalid periods
# Failed to process MFH: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "FONR" not found or invalid periods
# Failed to process FONR: 'Close'
# ...
# Failed to process ATNF: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "PRFX" not found or invalid periods
# Failed to process PRFX: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "LGMK" not found or invalid periods
# Failed to process LGMK: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "DRMA" not found or invalid periods
# Failed to process DRMA: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "LSDI" not found or invalid periods
# Failed to process LSDI: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CAMP" not found or invalid periods
# Failed to process CAMP: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "UK" not found or invalid periods
# Failed to process UK: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "QLGN" not found or invalid periods
# Failed to process QLGN: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BJDX" not found or invalid periods
# Failed to process BJDX: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CNEY" not found or invalid periods
# Failed to process CNEY: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CNSP" not found or invalid periods
# Failed to process CNSP: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SYTA" not found or invalid periods
# Failed to process SYTA: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "GRI" not found or invalid periods
# Failed to process GRI: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "QNRX" not found or invalid periods
# Failed to process QNRX: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SPRC" not found or invalid periods
# Failed to process SPRC: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SXTC" not found or invalid periods
# Failed to process SXTC: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CBRGU" not found or invalid periods
# Failed to process CBRGU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SMFL" not found or invalid periods
# Failed to process SMFL: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "FRMEP" not found or invalid periods
# Failed to process FRMEP: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BHFAL" not found or invalid periods
# Failed to process BHFAL: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "OPINL" not found or invalid periods
# Failed to process OPINL: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "MAXNV" not found or invalid periods
# Failed to process MAXNV: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "MCACR" not found or invalid periods
# Failed to process MCACR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SPWRV" not found or invalid periods
# Failed to process SPWRV: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SPEL" not found or invalid periods
# Failed to process SPEL: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "MVNR" not found or invalid periods
# Failed to process MVNR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BREZR" not found or invalid periods
# Failed to process BREZR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "HROWL" not found or invalid periods
# Failed to process HROWL: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "RILYK" not found or invalid periods
# Failed to process RILYK: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SNCRL" not found or invalid periods
# Failed to process SNCRL: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "METCL" not found or invalid periods
# Failed to process METCL: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "RILYZ" not found or invalid periods
# Failed to process RILYZ: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "IMAQR" not found or invalid periods
# Failed to process IMAQR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "WHLRL" not found or invalid periods
# Failed to process WHLRL: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CLOER" not found or invalid periods
# Failed to process CLOER: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "NOVVR" not found or invalid periods
# Failed to process NOVVR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "WINVR" not found or invalid periods
# Failed to process WINVR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "GREEL" not found or invalid periods
# Failed to process GREEL: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BNIXR" not found or invalid periods
# Failed to process BNIXR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "FOSLL" not found or invalid periods
# Failed to process FOSLL: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ATLCL" not found or invalid periods
# Failed to process ATLCL: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "MCAGR" not found or invalid periods
# Failed to process MCAGR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ARBKL" not found or invalid periods
# Failed to process ARBKL: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "HHGCR" not found or invalid periods
# Failed to process HHGCR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "RILYG" not found or invalid periods
# Failed to process RILYG: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "GLLIR" not found or invalid periods
# Failed to process GLLIR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BLEUR" not found or invalid periods
# Failed to process BLEUR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "FEXDR" not found or invalid periods
# Failed to process FEXDR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "KACLR" not found or invalid periods
# Failed to process KACLR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "IGTAR" not found or invalid periods
# Failed to process IGTAR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ALSAR" not found or invalid periods
# Failed to process ALSAR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "WTMAR" not found or invalid periods
# Failed to process WTMAR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "NVACR" not found or invalid periods
# Failed to process NVACR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BRACR" not found or invalid periods
# Failed to process BRACR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CSLMR" not found or invalid periods
# Failed to process CSLMR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BWAQR" not found or invalid periods
# Failed to process BWAQR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "RFACR" not found or invalid periods
# Failed to process RFACR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "GDSTR" not found or invalid periods
# Failed to process GDSTR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ASCBR" not found or invalid periods
# Failed to process ASCBR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "RWODR" not found or invalid periods
# Failed to process RWODR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "MSSAR" not found or invalid periods
# Failed to process MSSAR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CLRCR" not found or invalid periods
# Failed to process CLRCR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "GBBKR" not found or invalid periods
# Failed to process GBBKR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "YOTAR" not found or invalid periods
# Failed to process YOTAR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "FLFVR" not found or invalid periods
# Failed to process FLFVR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "EMCGR" not found or invalid periods
# Failed to process EMCGR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "AQUNR" not found or invalid periods
# Failed to process AQUNR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SVIIR" not found or invalid periods
# Failed to process SVIIR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "GLSTR" not found or invalid periods
# Failed to process GLSTR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "QOMOR" not found or invalid periods
# Failed to process QOMOR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "TENKR" not found or invalid periods
# Failed to process TENKR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "HUDAR" not found or invalid periods
# Failed to process HUDAR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "HROWM" not found or invalid periods
# Failed to process HROWM: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "PLTNR" not found or invalid periods
# Failed to process PLTNR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ATMCR" not found or invalid periods
# Failed to process ATMCR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ATMVR" not found or invalid periods
# Failed to process ATMVR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "HSPOR" not found or invalid periods
# Failed to process HSPOR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BLACR" not found or invalid periods
# Failed to process BLACR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "MARXR" not found or invalid periods
# Failed to process MARXR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "DISTR" not found or invalid periods
# Failed to process DISTR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CETUR" not found or invalid periods
# Failed to process CETUR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "TMTCR" not found or invalid periods
# Failed to process TMTCR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "TBMCR" not found or invalid periods
# Failed to process TBMCR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "OAKUR" not found or invalid periods
# Failed to process OAKUR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "GODNR" not found or invalid periods
# Failed to process GODNR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ESHAR" not found or invalid periods
# Failed to process ESHAR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BOWNR" not found or invalid periods
# Failed to process BOWNR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BUJAR" not found or invalid periods
# Failed to process BUJAR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SWKHL" not found or invalid periods
# Failed to process SWKHL: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "NNAGR" not found or invalid periods
# Failed to process NNAGR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "GLACR" not found or invalid periods
# Failed to process GLACR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ABLLL" not found or invalid periods
# Failed to process ABLLL: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "QETAR" not found or invalid periods
# Failed to process QETAR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BAYAR" not found or invalid periods
# Failed to process BAYAR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "AITRR" not found or invalid periods
# Failed to process AITRR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "IBLUU" not found or invalid periods
# Failed to process IBLUU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "AFJKR" not found or invalid periods
# Failed to process AFJKR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "PMNT" not found or invalid periods
# Failed to process PMNT: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ATLCZ" not found or invalid periods
# Failed to process ATLCZ: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "IROHR" not found or invalid periods
# Failed to process IROHR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "JVSAR" not found or invalid periods
# Failed to process JVSAR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "DYCQR" not found or invalid periods
# Failed to process DYCQR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "IBACR" not found or invalid periods
# Failed to process IBACR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BKHAR" not found or invalid periods
# Failed to process BKHAR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "NEWTG" not found or invalid periods
# Failed to process NEWTG: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SIFYR" not found or invalid periods
# Failed to process SIFYR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "WAY" not found or invalid periods
# Failed to process WAY: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "RAPP" not found or invalid periods
# Failed to process RAPP: 'Close'
# 조건에 맞는 상위 10개 종목 목록:
#    Symbol  Current Price  Recent Close    Trend    Buy Range  First Buy  \
# 2    SOFI           6.99          6.99  Uptrend  6.85 - 7.13     6.8502
# 0     WBD           8.27          8.27  Uptrend  8.10 - 8.44     8.1046
# 10   JBLU           5.56          5.56  Uptrend  5.45 - 5.67     5.4488
# 1    ERIC           6.22          6.22  Uptrend  6.10 - 6.34     6.0956
# 17   CORZ           7.78          7.78  Uptrend  7.62 - 7.94     7.6244
# 26   LESL           5.12          5.12  Uptrend  5.02 - 5.22     5.0176
# 6    ASTS           8.62          8.62  Uptrend  8.45 - 8.79     8.4476
# 20   SHLS           6.81          6.81  Uptrend  6.67 - 6.95     6.6738
# 28    HUT           9.68          9.68  Uptrend  9.49 - 9.87     9.4864
# 56   BYND           7.59          7.59  Uptrend  7.44 - 7.74     7.4382
#
#     Second Buy  Third Buy  Take Profit  Stop Loss    Avg Volume  Volatility  \
# 2         6.99     7.1298        7.689     6.6405  4.359280e+07    1.304543
# 0         8.27     8.4354        9.097     7.8565  2.311970e+07    2.222927
# 10        5.56     5.6712        6.116     5.2820  1.371437e+07    1.343962
# 1         6.22     6.3444        6.842     5.9090  1.197217e+07    0.438418
# 17        7.78     7.9356        8.558     7.3910  4.792725e+06    0.924105
# 26        5.12     5.2224        5.632     4.8640  3.742974e+06    2.991279
# 6         8.62     8.7924        9.482     8.1890  3.541542e+06    1.372631
# 20        6.81     6.9462        7.491     6.4695  3.470951e+06    6.020324
# 28        9.68     9.8736       10.648     9.1960  3.236508e+06    2.908045
# 56        7.59     7.7418        8.349     7.2105  2.881674e+06    3.800554
#
#         Phase
# 2    Sleeping
# 0    Sleeping
# 10   Sleeping
# 1      Eating
# 17   Sleeping
# 26  Awakening
# 6   Awakening
# 20   Sleeping
# 28  Awakening
# 56  Awakening
# <h2>조건에 맞는 상위 10개 NASDAQ 종목 목록</h2>
#    Symbol  Current Price  Recent Close    Trend    Buy Range  First Buy  \
# 2    SOFI           6.99          6.99  Uptrend  6.85 - 7.13     6.8502
# 0     WBD           8.27          8.27  Uptrend  8.10 - 8.44     8.1046
# 10   JBLU           5.56          5.56  Uptrend  5.45 - 5.67     5.4488
# 1    ERIC           6.22          6.22  Uptrend  6.10 - 6.34     6.0956
# 17   CORZ           7.78          7.78  Uptrend  7.62 - 7.94     7.6244
# 26   LESL           5.12          5.12  Uptrend  5.02 - 5.22     5.0176
# 6    ASTS           8.62          8.62  Uptrend  8.45 - 8.79     8.4476
# 20   SHLS           6.81          6.81  Uptrend  6.67 - 6.95     6.6738
# 28    HUT           9.68          9.68  Uptrend  9.49 - 9.87     9.4864
# 56   BYND           7.59          7.59  Uptrend  7.44 - 7.74     7.4382
#
#     Second Buy  Third Buy  Take Profit  Stop Loss    Avg Volume  Volatility  \
# 2         6.99     7.1298        7.689     6.6405  4.359280e+07    1.304543
# 0         8.27     8.4354        9.097     7.8565  2.311970e+07    2.222927
# 10        5.56     5.6712        6.116     5.2820  1.371437e+07    1.343962
# 1         6.22     6.3444        6.842     5.9090  1.197217e+07    0.438418
# 17        7.78     7.9356        8.558     7.3910  4.792725e+06    0.924105
# 26        5.12     5.2224        5.632     4.8640  3.742974e+06    2.991279
# 6         8.62     8.7924        9.482     8.1890  3.541542e+06    1.372631
# 20        6.81     6.9462        7.491     6.4695  3.470951e+06    6.020324
# 28        9.68     9.8736       10.648     9.1960  3.236508e+06    2.908045
# 56        7.59     7.7418        8.349     7.2105  2.881674e+06    3.800554
#
#         Phase
# 2    Sleeping
# 0    Sleeping
# 10   Sleeping
# 1      Eating
# 17   Sleeping
# 26  Awakening
# 6   Awakening
# 20   Sleeping
# 28  Awakening
# 56  Awakening

# %% [markdown]
# 필요한 패키지 설치

# %%
# !apt-get install -y fonts-nanum
# !fc-cache -fv
# !rm -rf ~/.cache/matplotlib

# FinanceDataReader 설치
# !pip install finance-datareader
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-nanum is already the newest version (20200506-1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# /usr/share/fonts/truetype/nanum: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded
# Requirement already satisfied: finance-datareader in /usr/local/lib/python3.10/dist-packages (0.9.90)
# Requirement already satisfied: pandas>=0.19.2 in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (2.0.3)
# Requirement already satisfied: requests>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (2.31.0)
# Requirement already satisfied: requests-file in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (2.1.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (4.9.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (4.66.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19.2->finance-datareader) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19.2->finance-datareader) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19.2->finance-datareader) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19.2->finance-datareader) (1.25.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (2024.6.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=0.19.2->finance-datareader) (1.16.0)

# %% [markdown]
# 라이브러리 임포트 및 폰트 설정

# %%
import matplotlib.pyplot as plt
import FinanceDataReader as fdr
import pandas as pd
import numpy as np
from datetime import datetime

plt.rcParams['font.family'] = 'NanumBarunGothic'  # 한글 출력을 위한 폰트 설정

# %% [markdown]
# NASDAQ 상장 목록 가져오기

# %%
nasdaq_list = fdr.StockListing('NASDAQ')

# 데이터프레임의 열 이름 확인
print(nasdaq_list.columns)

# 열 이름 확인 후 'Symbol' 열 사용
symbol_column_name = 'Symbol'
close_column_name = 'Close'

# 필터링 조건
price_lower = 5
price_upper = 10

# 필터링된 데이터프레임 저장용 리스트
filtered_stocks_data = []

# 오늘 날짜 구하기
today = datetime.today().strftime('%Y-%m-%d')
# Out:
# 100%|██████████| 3765/3765 [00:18<00:00, 202.14it/s]
# Index(['Symbol', 'Name', 'IndustryCode', 'Industry'], dtype='object')

# %% [markdown]
# 각 종목의 데이터를 가져와서 조건에 맞는지 확인 및 상태 식별

# %%
for symbol in nasdaq_list[symbol_column_name]:
    try:
        # 종목 데이터 불러오기 (2023-01-02부터 오늘까지)
        data = fdr.DataReader(symbol, '2023-01-02', today)

        # 종가가 5-10 달러 사이에 있는지 확인
        if data[close_column_name].iloc[-1] < price_lower or data[close_column_name].iloc[-1] > price_upper:
            continue

        # 이동 평균 계산
        data['SMA20'] = data[close_column_name].rolling(window=20).mean()
        data['SMA50'] = data[close_column_name].rolling(window=50).mean()
        data['SMA200'] = data[close_column_name].rolling(window=200).mean()

        # 거래량 평균 계산
        avg_volume = data['Volume'].mean()

        # 변동폭 계산 (종가의 표준편차)
        volatility = data[close_column_name].std()

        # MACD 및 시그널 계산
        exp1 = data[close_column_name].ewm(span=12, adjust=False).mean()
        exp2 = data[close_column_name].ewm(span=26, adjust=False).mean()
        macd = exp1 - exp2
        signal = macd.ewm(span=9, adjust=False).mean()

        # 가장 최근 종가
        recent_close = data[close_column_name].iloc[-1]

        # 추세 계산
        trend = 'Uptrend' if macd.iloc[-1] > signal.iloc[-1] else 'Downtrend'

        # 매수가 범위 계산 (±2%)
        buy_range_low = recent_close * 0.98
        buy_range_high = recent_close * 1.02

        # 1차, 2차, 3차 매수가
        first_buy = buy_range_low
        second_buy = (buy_range_low + buy_range_high) / 2
        third_buy = buy_range_high

        # 익절가 (최근 종가의 +10%)
        take_profit = recent_close * 1.10

        # 손절가 (최근 종가의 -5%)
        stop_loss = recent_close * 0.95

        # 상태 식별
        data['Phase'] = 'Sleeping'
        conditions = [
            (data['SMA20'] > data['SMA50']) & (data['SMA50'] > data['SMA200']),
            (data['SMA20'] > data['SMA50']) & (data['SMA50'] < data['SMA200']),
        ]
        choices = ['Eating', 'Awakening']
        data['Phase'] = np.select(conditions, choices, default='Sleeping')

        # 조건 필터링
        if macd.iloc[-1] > signal.iloc[-1]:  # MACD 매수 시그널
            filtered_stocks_data.append({
                'Symbol': symbol,
                'Current Price': recent_close,
                'Recent Close': recent_close,
                'Trend': trend,
                'Buy Range': f"{buy_range_low:.2f} - {buy_range_high:.2f}",
                'First Buy': first_buy,
                'Second Buy': second_buy,
                'Third Buy': third_buy,
                'Take Profit': take_profit,
                'Stop Loss': stop_loss,
                'Avg Volume': avg_volume,
                'Volatility': volatility,
                'Phase': data['Phase'].iloc[-1]
            })
    except Exception as e:
        # 데이터 불러오기에 실패하면 무시
        print(f"Failed to process {symbol}: {e}")
        continue
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# HTTP Error 429: Too Many Requests  - symbol "HBNC" not found or invalid periods
# Failed to process HBNC: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "TRST" not found or invalid periods
# Failed to process TRST: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "FULC" not found or invalid periods
# Failed to process FULC: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "RBBN" not found or invalid periods
# Failed to process RBBN: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CNSL" not found or invalid periods
# Failed to process CNSL: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "FNKO" not found or invalid periods
# Failed to process FNKO: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "MNMD" not found or invalid periods
# Failed to process MNMD: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "GAIN" not found or invalid periods
# Failed to process GAIN: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CMPO" not found or invalid periods
# Failed to process CMPO: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "APLT" not found or invalid periods
# Failed to process APLT: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CATC" not found or invalid periods
# Failed to process CATC: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "IBCP" not found or invalid periods
# Failed to process IBCP: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "FWRD" not found or invalid periods
# Failed to process FWRD: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CRESY" not found or invalid periods
# Failed to process CRESY: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "EXAI" not found or invalid periods
# Failed to process EXAI: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "OSPN" not found or invalid periods
# Failed to process OSPN: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CDMO" not found or invalid periods
# Failed to process CDMO: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "OFIX" not found or invalid periods
# Failed to process OFIX: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "PWFL" not found or invalid periods
# Failed to process PWFL: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "MGIC" not found or invalid periods
# Failed to process MGIC: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CHSCM" not found or invalid periods
# Failed to process CHSCM: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BYND" not found or invalid periods
# Failed to process BYND: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "MXCT" not found or invalid periods
# Failed to process MXCT: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CCRN" not found or invalid periods
# Failed to process CCRN: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "RSVR" not found or invalid periods
# Failed to process RSVR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "DJCO" not found or invalid periods
# Failed to process DJCO: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CELC" not found or invalid periods
# Failed to process CELC: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ALLO" not found or invalid periods
# Failed to process ALLO: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "KALV" not found or invalid periods
# Failed to process KALV: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SVCO" not found or invalid periods
# Failed to process SVCO: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CTLP" not found or invalid periods
# Failed to process CTLP: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "TSAT" not found or invalid periods
# Failed to process TSAT: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CRBP" not found or invalid periods
# Failed to process CRBP: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "GLAD" not found or invalid periods
# Failed to process GLAD: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "RXT" not found or invalid periods
# Failed to process RXT: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "AVAH" not found or invalid periods
# Failed to process AVAH: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ABSI" not found or invalid periods
# Failed to process ABSI: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BRY" not found or invalid periods
# Failed to process BRY: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "IPHA" not found or invalid periods
# Failed to process IPHA: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "COOLU" not found or invalid periods
# Failed to process COOLU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "HTBK" not found or invalid periods
# Failed to process HTBK: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ATXS" not found or invalid periods
# Failed to process ATXS: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "FSBC" not found or invalid periods
# Failed to process FSBC: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "MSBI" not found or invalid periods
# Failed to process MSBI: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "IGMS" not found or invalid periods
# Failed to process IGMS: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ALXO" not found or invalid periods
# Failed to process ALXO: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ACIU" not found or invalid periods
# Failed to process ACIU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "EYPT" not found or invalid periods
# Failed to process EYPT: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "MREO" not found or invalid periods
# Failed to process MREO: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "HTBI" not found or invalid periods
# Failed to process HTBI: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "LAND" not found or invalid periods
# Failed to process LAND: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "NGNE" not found or invalid periods
# Failed to process NGNE: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ONEW" not found or invalid periods
# Failed to process ONEW: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "RWAY" not found or invalid periods
# Failed to process RWAY: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CEVA" not found or invalid periods
# Failed to process CEVA: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ALT" not found or invalid periods
# Failed to process ALT: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "URGN" not found or invalid periods
# Failed to process URGN: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "NCMI" not found or invalid periods
# Failed to process NCMI: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CAC" not found or invalid periods
# Failed to process CAC: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "MCBC" not found or invalid periods
# Failed to process MCBC: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "NKTX" not found or invalid periods
# Failed to process NKTX: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CMPS" not found or invalid periods
# Failed to process CMPS: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "HAFC" not found or invalid periods
# Failed to process HAFC: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SMBC" not found or invalid periods
# Failed to process SMBC: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "TERN" not found or invalid periods
# Failed to process TERN: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "NNOX" not found or invalid periods
# Failed to process NNOX: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ESPR" not found or invalid periods
# Failed to process ESPR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "PAL" not found or invalid periods
# Failed to process PAL: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "FITBI" not found or invalid periods
# Failed to process FITBI: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "TMC" not found or invalid periods
# Failed to process TMC: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SFIX" not found or invalid periods
# Failed to process SFIX: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CCBG" not found or invalid periods
# Failed to process CCBG: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "VYGR" not found or invalid periods
# Failed to process VYGR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "HONE" not found or invalid periods
# Failed to process HONE: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "TCRX" not found or invalid periods
# Failed to process TCRX: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "GMGI" not found or invalid periods
# Failed to process GMGI: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CHUY" not found or invalid periods
# Failed to process CHUY: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "DAVE" not found or invalid periods
# Failed to process DAVE: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "RDUS" not found or invalid periods
# Failed to process RDUS: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "FMNB" not found or invalid periods
# Failed to process FMNB: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CDLX" not found or invalid periods
# Failed to process CDLX: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "LNZA" not found or invalid periods
# Failed to process LNZA: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "TALK" not found or invalid periods
# Failed to process TALK: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BHFAN" not found or invalid periods
# Failed to process BHFAN: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ZIMV" not found or invalid periods
# Failed to process ZIMV: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "EDIT" not found or invalid periods
# Failed to process EDIT: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CHSCN" not found or invalid periods
# Failed to process CHSCN: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SHYF" not found or invalid periods
# Failed to process SHYF: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "OCGN" not found or invalid periods
# Failed to process OCGN: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "FAAS" not found or invalid periods
# Failed to process FAAS: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "PPTA" not found or invalid periods
# Failed to process PPTA: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "NEXN" not found or invalid periods
# Failed to process NEXN: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "VERV" not found or invalid periods
# Failed to process VERV: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CVGW" not found or invalid periods
# Failed to process CVGW: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ANSC" not found or invalid periods
# Failed to process ANSC: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "WASH" not found or invalid periods
# Failed to process WASH: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ZJYL" not found or invalid periods
# Failed to process ZJYL: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SWIM" not found or invalid periods
# Failed to process SWIM: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "LYTS" not found or invalid periods
# Failed to process LYTS: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "WLDN" not found or invalid periods
# Failed to process WLDN: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BATRA" not found or invalid periods
# Failed to process BATRA: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "REPL" not found or invalid periods
# Failed to process REPL: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "INOD" not found or invalid periods
# Failed to process INOD: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ICG" not found or invalid periods
# Failed to process ICG: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SPFI" not found or invalid periods
# Failed to process SPFI: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "NBN" not found or invalid periods
# Failed to process NBN: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CHW" not found or invalid periods
# Failed to process CHW: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "FATE" not found or invalid periods
# Failed to process FATE: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "TBPH" not found or invalid periods
# Failed to process TBPH: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "PGEN" not found or invalid periods
# Failed to process PGEN: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "DADA" not found or invalid periods
# Failed to process DADA: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "THFF" not found or invalid periods
# Failed to process THFF: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ALNT" not found or invalid periods
# Failed to process ALNT: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "MKTW" not found or invalid periods
# Failed to process MKTW: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SOHU" not found or invalid periods
# Failed to process SOHU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "RICK" not found or invalid periods
# Failed to process RICK: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ALEC" not found or invalid periods
# Failed to process ALEC: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ADTN" not found or invalid periods
# Failed to process ADTN: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SLRN" not found or invalid periods
# Failed to process SLRN: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "HRZN" not found or invalid periods
# Failed to process HRZN: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "LOVE" not found or invalid periods
# Failed to process LOVE: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CRMT" not found or invalid periods
# Failed to process CRMT: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BTMD" not found or invalid periods
# Failed to process BTMD: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "AROW" not found or invalid periods
# Failed to process AROW: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "NTGR" not found or invalid periods
# Failed to process NTGR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "DHIL" not found or invalid periods
# Failed to process DHIL: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "FCEL" not found or invalid periods
# Failed to process FCEL: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "KRRO" not found or invalid periods
# Failed to process KRRO: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CTNM" not found or invalid periods
# Failed to process CTNM: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "IMMP" not found or invalid periods
# Failed to process IMMP: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "HDSN" not found or invalid periods
# Failed to process HDSN: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CWCO" not found or invalid periods
# Failed to process CWCO: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "LE" not found or invalid periods
# Failed to process LE: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "TITN" not found or invalid periods
# Failed to process TITN: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "WLFC" not found or invalid periods
# Failed to process WLFC: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "IPX" not found or invalid periods
# Failed to process IPX: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "LIND" not found or invalid periods
# Failed to process LIND: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BMEA" not found or invalid periods
# Failed to process BMEA: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BBCP" not found or invalid periods
# Failed to process BBCP: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CCNE" not found or invalid periods
# Failed to process CCNE: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "AAOI" not found or invalid periods
# Failed to process AAOI: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ESGRP" not found or invalid periods
# Failed to process ESGRP: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "REAL" not found or invalid periods
# Failed to process REAL: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "AGNCO" not found or invalid periods
# Failed to process AGNCO: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "EVLV" not found or invalid periods
# Failed to process EVLV: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "GDEV" not found or invalid periods
# Failed to process GDEV: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "VLGEA" not found or invalid periods
# Failed to process VLGEA: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ISPR" not found or invalid periods
# Failed to process ISPR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "IVCBU" not found or invalid periods
# Failed to process IVCBU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BHFAP" not found or invalid periods
# Failed to process BHFAP: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BPYPM" not found or invalid periods
# Failed to process BPYPM: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ACGLN" not found or invalid periods
# Failed to process ACGLN: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BHFAO" not found or invalid periods
# Failed to process BHFAO: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ZUMZ" not found or invalid periods
# Failed to process ZUMZ: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "AVNW" not found or invalid periods
# Failed to process AVNW: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ATLC" not found or invalid periods
# Failed to process ATLC: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "HCAT" not found or invalid periods
# Failed to process HCAT: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ANIK" not found or invalid periods
# Failed to process ANIK: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CHSCP" not found or invalid periods
# Failed to process CHSCP: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "TWLVU" not found or invalid periods
# Failed to process TWLVU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ESQ" not found or invalid periods
# Failed to process ESQ: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "AEHR" not found or invalid periods
# Failed to process AEHR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "LENZ" not found or invalid periods
# Failed to process LENZ: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "JSPR" not found or invalid periods
# Failed to process JSPR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "HCVIU" not found or invalid periods
# Failed to process HCVIU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ECX" not found or invalid periods
# Failed to process ECX: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "MODV" not found or invalid periods
# Failed to process MODV: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "TMCI" not found or invalid periods
# Failed to process TMCI: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "GGR" not found or invalid periods
# Failed to process GGR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ASLE" not found or invalid periods
# Failed to process ASLE: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "PGC" not found or invalid periods
# Failed to process PGC: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ALRS" not found or invalid periods
# Failed to process ALRS: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "HIFS" not found or invalid periods
# Failed to process HIFS: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "RGP" not found or invalid periods
# Failed to process RGP: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CCSI" not found or invalid periods
# Failed to process CCSI: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "JFIN" not found or invalid periods
# Failed to process JFIN: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "DENN" not found or invalid periods
# Failed to process DENN: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "VRCA" not found or invalid periods
# Failed to process VRCA: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SKYT" not found or invalid periods
# Failed to process SKYT: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "NVEC" not found or invalid periods
# Failed to process NVEC: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BTSGU" not found or invalid periods
# Failed to process BTSGU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "AURA" not found or invalid periods
# Failed to process AURA: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "FFIC" not found or invalid periods
# Failed to process FFIC: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "COMM" not found or invalid periods
# Failed to process COMM: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "LMNR" not found or invalid periods
# Failed to process LMNR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "PANL" not found or invalid periods
# Failed to process PANL: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "JOUT" not found or invalid periods
# Failed to process JOUT: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "DGICA" not found or invalid periods
# Failed to process DGICA: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "VNDA" not found or invalid periods
# Failed to process VNDA: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "NEGG" not found or invalid periods
# Failed to process NEGG: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SGC" not found or invalid periods
# Failed to process SGC: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SHBI" not found or invalid periods
# Failed to process SHBI: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ATNI" not found or invalid periods
# Failed to process ATNI: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "NFBK" not found or invalid periods
# Failed to process NFBK: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "LSEA" not found or invalid periods
# Failed to process LSEA: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CCIXU" not found or invalid periods
# Failed to process CCIXU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "OSUR" not found or invalid periods
# Failed to process OSUR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ANSCU" not found or invalid periods
# Failed to process ANSCU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "QIWI" not found or invalid periods
# Failed to process QIWI: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ORGO" not found or invalid periods
# Failed to process ORGO: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "PTSI" not found or invalid periods
# Failed to process PTSI: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "VALU" not found or invalid periods
# Failed to process VALU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "HBANP" not found or invalid periods
# Failed to process HBANP: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "KRNY" not found or invalid periods
# Failed to process KRNY: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "MPB" not found or invalid periods
# Failed to process MPB: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "XERS" not found or invalid periods
# Failed to process XERS: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CERS" not found or invalid periods
# Failed to process CERS: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "MCFT" not found or invalid periods
# Failed to process MCFT: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "LILA" not found or invalid periods
# Failed to process LILA: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BCSAU" not found or invalid periods
# Failed to process BCSAU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "TRML" not found or invalid periods
# Failed to process TRML: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "AGEN" not found or invalid periods
# Failed to process AGEN: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ENGN" not found or invalid periods
# Failed to process ENGN: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "PRTH" not found or invalid periods
# Failed to process PRTH: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "STTK" not found or invalid periods
# Failed to process STTK: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "PWUPU" not found or invalid periods
# Failed to process PWUPU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "GPACU" not found or invalid periods
# Failed to process GPACU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "FHTX" not found or invalid periods
# Failed to process FHTX: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SGHT" not found or invalid periods
# Failed to process SGHT: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "FARO" not found or invalid periods
# Failed to process FARO: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "GENK" not found or invalid periods
# Failed to process GENK: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "AMSWA" not found or invalid periods
# Failed to process AMSWA: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "AVXL" not found or invalid periods
# Failed to process AVXL: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "AIRTP" not found or invalid periods
# Failed to process AIRTP: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "IRAAU" not found or invalid periods
# Failed to process IRAAU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BTBT" not found or invalid periods
# Failed to process BTBT: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ONYXU" not found or invalid periods
# Failed to process ONYXU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "NTRSO" not found or invalid periods
# Failed to process NTRSO: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "FORR" not found or invalid periods
# Failed to process FORR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "NWPX" not found or invalid periods
# Failed to process NWPX: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "FBLG" not found or invalid periods
# Failed to process FBLG: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "LFMD" not found or invalid periods
# Failed to process LFMD: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "AGNCN" not found or invalid periods
# Failed to process AGNCN: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "PPYAU" not found or invalid periods
# Failed to process PPYAU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "NAUT" not found or invalid periods
# Failed to process NAUT: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "PLMIU" not found or invalid periods
# Failed to process PLMIU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ACABU" not found or invalid periods
# Failed to process ACABU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "KRNLU" not found or invalid periods
# Failed to process KRNLU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CDRO" not found or invalid periods
# Failed to process CDRO: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "LWLG" not found or invalid periods
# Failed to process LWLG: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SOPH" not found or invalid periods
# Failed to process SOPH: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "IPXXU" not found or invalid periods
# Failed to process IPXXU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "HIVE" not found or invalid periods
# Failed to process HIVE: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "IPXX" not found or invalid periods
# Failed to process IPXX: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SNBR" not found or invalid periods
# Failed to process SNBR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "HEAR" not found or invalid periods
# Failed to process HEAR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "LOCO" not found or invalid periods
# Failed to process LOCO: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "HBANL" not found or invalid periods
# Failed to process HBANL: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "LINC" not found or invalid periods
# Failed to process LINC: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "MOFG" not found or invalid periods
# Failed to process MOFG: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ACB" not found or invalid periods
# Failed to process ACB: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ARTNA" not found or invalid periods
# Failed to process ARTNA: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "DCGO" not found or invalid periods
# Failed to process DCGO: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "HNRG" not found or invalid periods
# Failed to process HNRG: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "NEWT" not found or invalid periods
# Failed to process NEWT: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SENEA" not found or invalid periods
# Failed to process SENEA: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "IMMR" not found or invalid periods
# Failed to process IMMR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "NETDU" not found or invalid periods
# Failed to process NETDU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CCCC" not found or invalid periods
# Failed to process CCCC: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "RBB" not found or invalid periods
# Failed to process RBB: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CWBC" not found or invalid periods
# Failed to process CWBC: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "EGHT" not found or invalid periods
# Failed to process EGHT: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "NETD" not found or invalid periods
# Failed to process NETD: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ITIC" not found or invalid periods
# Failed to process ITIC: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "GATEU" not found or invalid periods
# Failed to process GATEU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "AVIR" not found or invalid periods
# Failed to process AVIR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "MYPS" not found or invalid periods
# Failed to process MYPS: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BLNK" not found or invalid periods
# Failed to process BLNK: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SKYE" not found or invalid periods
# Failed to process SKYE: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "RRBI" not found or invalid periods
# Failed to process RRBI: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CAN" not found or invalid periods
# Failed to process CAN: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BRKHU" not found or invalid periods
# Failed to process BRKHU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "NODK" not found or invalid periods
# Failed to process NODK: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "MGTX" not found or invalid periods
# Failed to process MGTX: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SHCR" not found or invalid periods
# Failed to process SHCR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "DOYU" not found or invalid periods
# Failed to process DOYU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "GUTS" not found or invalid periods
# Failed to process GUTS: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "EMLDU" not found or invalid periods
# Failed to process EMLDU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "AIP" not found or invalid periods
# Failed to process AIP: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "MTRX" not found or invalid periods
# Failed to process MTRX: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "GASS" not found or invalid periods
# Failed to process GASS: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "PKOH" not found or invalid periods
# Failed to process PKOH: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "NYXH" not found or invalid periods
# Failed to process NYXH: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "PMTS" not found or invalid periods
# Failed to process PMTS: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "AXGN" not found or invalid periods
# Failed to process AXGN: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "STRO" not found or invalid periods
# Failed to process STRO: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "PROC" not found or invalid periods
# Failed to process PROC: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ZYXI" not found or invalid periods
# Failed to process ZYXI: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "POWW" not found or invalid periods
# Failed to process POWW: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "GAMCU" not found or invalid periods
# Failed to process GAMCU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "AFRI" not found or invalid periods
# Failed to process AFRI: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "GAUZ" not found or invalid periods
# Failed to process GAUZ: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "VTRU" not found or invalid periods
# Failed to process VTRU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "TTEC" not found or invalid periods
# Failed to process TTEC: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CPZ" not found or invalid periods
# Failed to process CPZ: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "GWRS" not found or invalid periods
# Failed to process GWRS: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "AUDC" not found or invalid periods
# Failed to process AUDC: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "RVNC" not found or invalid periods
# Failed to process RVNC: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SLMBP" not found or invalid periods
# Failed to process SLMBP: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "TGAN" not found or invalid periods
# Failed to process TGAN: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "GILT" not found or invalid periods
# Failed to process GILT: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "MTLS" not found or invalid periods
# Failed to process MTLS: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "UROY" not found or invalid periods
# Failed to process UROY: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BWB" not found or invalid periods
# Failed to process BWB: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ACGLO" not found or invalid periods
# Failed to process ACGLO: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "EBTC" not found or invalid periods
# Failed to process EBTC: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "REFI" not found or invalid periods
# Failed to process REFI: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SPOK" not found or invalid periods
# Failed to process SPOK: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "APEI" not found or invalid periods
# Failed to process APEI: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BSRR" not found or invalid periods
# Failed to process BSRR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "NRIM" not found or invalid periods
# Failed to process NRIM: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "TTSH" not found or invalid periods
# Failed to process TTSH: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "LX" not found or invalid periods
# Failed to process LX: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "NBTX" not found or invalid periods
# Failed to process NBTX: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "FRBA" not found or invalid periods
# Failed to process FRBA: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "INZY" not found or invalid periods
# Failed to process INZY: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SLDP" not found or invalid periods
# Failed to process SLDP: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "KMDA" not found or invalid periods
# Failed to process KMDA: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "WHF" not found or invalid periods
# Failed to process WHF: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SLDB" not found or invalid periods
# Failed to process SLDB: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "JRVR" not found or invalid periods
# Failed to process JRVR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CARE" not found or invalid periods
# Failed to process CARE: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BLEUU" not found or invalid periods
# Failed to process BLEUU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "HBCP" not found or invalid periods
# Failed to process HBCP: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ADTH" not found or invalid periods
# Failed to process ADTH: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "NPABU" not found or invalid periods
# Failed to process NPABU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "MGNX" not found or invalid periods
# Failed to process MGNX: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "RDVT" not found or invalid periods
# Failed to process RDVT: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "TLS" not found or invalid periods
# Failed to process TLS: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "IONR" not found or invalid periods
# Failed to process IONR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "GPATU" not found or invalid periods
# Failed to process GPATU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "AMRN" not found or invalid periods
# Failed to process AMRN: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "TCMD" not found or invalid periods
# Failed to process TCMD: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "LSAK" not found or invalid periods
# Failed to process LSAK: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "WEYS" not found or invalid periods
# Failed to process WEYS: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "TNYA" not found or invalid periods
# Failed to process TNYA: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "QRTEA" not found or invalid periods
# Failed to process QRTEA: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "USAP" not found or invalid periods
# Failed to process USAP: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "UHG" not found or invalid periods
# Failed to process UHG: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "NATR" not found or invalid periods
# Failed to process NATR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "IRBT" not found or invalid periods
# Failed to process IRBT: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "WTFCP" not found or invalid periods
# Failed to process WTFCP: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "VMD" not found or invalid periods
# Failed to process VMD: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "OBIO" not found or invalid periods
# Failed to process OBIO: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "PEGRU" not found or invalid periods
# Failed to process PEGRU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CRMD" not found or invalid periods
# Failed to process CRMD: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "FSTR" not found or invalid periods
# Failed to process FSTR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "IVCAU" not found or invalid periods
# Failed to process IVCAU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "FBIZ" not found or invalid periods
# Failed to process FBIZ: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "GAMB" not found or invalid periods
# Failed to process GAMB: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "RCKY" not found or invalid periods
# Failed to process RCKY: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "NATH" not found or invalid periods
# Failed to process NATH: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "WTBA" not found or invalid periods
# Failed to process WTBA: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "FMAO" not found or invalid periods
# Failed to process FMAO: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CBNK" not found or invalid periods
# Failed to process CBNK: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "PFTAU" not found or invalid periods
# Failed to process PFTAU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "XOMA" not found or invalid periods
# Failed to process XOMA: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "IMAQU" not found or invalid periods
# Failed to process IMAQU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BSVN" not found or invalid periods
# Failed to process BSVN: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "VSTA" not found or invalid periods
# Failed to process VSTA: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SERA" not found or invalid periods
# Failed to process SERA: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "TCBX" not found or invalid periods
# Failed to process TCBX: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "LUNG" not found or invalid periods
# Failed to process LUNG: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "DHACU" not found or invalid periods
# Failed to process DHACU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CBUS" not found or invalid periods
# Failed to process CBUS: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "PFIS" not found or invalid periods
# Failed to process PFIS: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "FISI" not found or invalid periods
# Failed to process FISI: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ORRF" not found or invalid periods
# Failed to process ORRF: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "IBEX" not found or invalid periods
# Failed to process IBEX: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "MRSN" not found or invalid periods
# Failed to process MRSN: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "FCNCP" not found or invalid periods
# Failed to process FCNCP: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "GRIN" not found or invalid periods
# Failed to process GRIN: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ESEA" not found or invalid periods
# Failed to process ESEA: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "PLMJU" not found or invalid periods
# Failed to process PLMJU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "PSTX" not found or invalid periods
# Failed to process PSTX: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "VMCAU" not found or invalid periods
# Failed to process VMCAU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ZURA" not found or invalid periods
# Failed to process ZURA: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "MCAAU" not found or invalid periods
# Failed to process MCAAU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ENTA" not found or invalid periods
# Failed to process ENTA: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "UNTY" not found or invalid periods
# Failed to process UNTY: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "TLGYU" not found or invalid periods
# Failed to process TLGYU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "TRUE" not found or invalid periods
# Failed to process TRUE: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "FDBC" not found or invalid periods
# Failed to process FDBC: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CZNC" not found or invalid periods
# Failed to process CZNC: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ACNB" not found or invalid periods
# Failed to process ACNB: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ADAP" not found or invalid periods
# Failed to process ADAP: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "AEYE" not found or invalid periods
# Failed to process AEYE: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CLAR" not found or invalid periods
# Failed to process CLAR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BDTX" not found or invalid periods
# Failed to process BDTX: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "FSBW" not found or invalid periods
# Failed to process FSBW: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "THCPU" not found or invalid periods
# Failed to process THCPU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ANGO" not found or invalid periods
# Failed to process ANGO: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BYRN" not found or invalid periods
# Failed to process BYRN: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "PLAOU" not found or invalid periods
# Failed to process PLAOU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ILPT" not found or invalid periods
# Failed to process ILPT: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "FNLC" not found or invalid periods
# Failed to process FNLC: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "OBT" not found or invalid periods
# Failed to process OBT: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "INO" not found or invalid periods
# Failed to process INO: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SLAM" not found or invalid periods
# Failed to process SLAM: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "DOMO" not found or invalid periods
# Failed to process DOMO: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "GNFT" not found or invalid periods
# Failed to process GNFT: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "PBFS" not found or invalid periods
# Failed to process PBFS: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "RENEU" not found or invalid periods
# Failed to process RENEU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "MAMA" not found or invalid periods
# Failed to process MAMA: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "EPIX" not found or invalid periods
# Failed to process EPIX: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "EM" not found or invalid periods
# Failed to process EM: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "PLAO" not found or invalid periods
# Failed to process PLAO: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CLMB" not found or invalid periods
# Failed to process CLMB: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "QURE" not found or invalid periods
# Failed to process QURE: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SKIN" not found or invalid periods
# Failed to process SKIN: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "AQST" not found or invalid periods
# Failed to process AQST: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "HNST" not found or invalid periods
# Failed to process HNST: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "NKTR" not found or invalid periods
# Failed to process NKTR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "FRST" not found or invalid periods
# Failed to process FRST: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "GLUE" not found or invalid periods
# Failed to process GLUE: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SBT" not found or invalid periods
# Failed to process SBT: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "QDROU" not found or invalid periods
# Failed to process QDROU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "AGBA" not found or invalid periods
# Failed to process AGBA: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "INAQU" not found or invalid periods
# Failed to process INAQU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SMTI" not found or invalid periods
# Failed to process SMTI: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BLZE" not found or invalid periods
# Failed to process BLZE: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "AEAEU" not found or invalid periods
# Failed to process AEAEU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "IPSC" not found or invalid periods
# Failed to process IPSC: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SHIP" not found or invalid periods
# Failed to process SHIP: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CMCAU" not found or invalid periods
# Failed to process CMCAU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "VBNK" not found or invalid periods
# Failed to process VBNK: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "RMNI" not found or invalid periods
# Failed to process RMNI: 'Close'
# ...
# Failed to process CYCCP: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "STAF" not found or invalid periods
# Failed to process STAF: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ACON" not found or invalid periods
# Failed to process ACON: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "AGRI" not found or invalid periods
# Failed to process AGRI: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "TNON" not found or invalid periods
# Failed to process TNON: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SCNI" not found or invalid periods
# Failed to process SCNI: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "JFBR" not found or invalid periods
# Failed to process JFBR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "TIVC" not found or invalid periods
# Failed to process TIVC: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BNRG" not found or invalid periods
# Failed to process BNRG: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "IVP" not found or invalid periods
# Failed to process IVP: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "WORX" not found or invalid periods
# Failed to process WORX: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "NITO" not found or invalid periods
# Failed to process NITO: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "GLMD" not found or invalid periods
# Failed to process GLMD: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "NAOV" not found or invalid periods
# Failed to process NAOV: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "GNLN" not found or invalid periods
# Failed to process GNLN: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "DYNT" not found or invalid periods
# Failed to process DYNT: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "INM" not found or invalid periods
# Failed to process INM: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "NUZE" not found or invalid periods
# Failed to process NUZE: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "NCPL" not found or invalid periods
# Failed to process NCPL: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "AREB" not found or invalid periods
# Failed to process AREB: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SLRX" not found or invalid periods
# Failed to process SLRX: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "RELI" not found or invalid periods
# Failed to process RELI: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "MYSZ" not found or invalid periods
# Failed to process MYSZ: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "NDRA" not found or invalid periods
# Failed to process NDRA: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "WINT" not found or invalid periods
# Failed to process WINT: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "MBIO" not found or invalid periods
# Failed to process MBIO: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "LYT" not found or invalid periods
# Failed to process LYT: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "LGHL" not found or invalid periods
# Failed to process LGHL: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BRSH" not found or invalid periods
# Failed to process BRSH: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "NTRP" not found or invalid periods
# Failed to process NTRP: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "TBLT" not found or invalid periods
# Failed to process TBLT: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "EAST" not found or invalid periods
# Failed to process EAST: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BBLG" not found or invalid periods
# Failed to process BBLG: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "VRPX" not found or invalid periods
# Failed to process VRPX: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ATNF" not found or invalid periods
# Failed to process ATNF: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "PRFX" not found or invalid periods
# Failed to process PRFX: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "LGMK" not found or invalid periods
# Failed to process LGMK: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "DRMA" not found or invalid periods
# Failed to process DRMA: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "LSDI" not found or invalid periods
# Failed to process LSDI: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CAMP" not found or invalid periods
# Failed to process CAMP: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "UK" not found or invalid periods
# Failed to process UK: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "QLGN" not found or invalid periods
# Failed to process QLGN: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BJDX" not found or invalid periods
# Failed to process BJDX: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CNEY" not found or invalid periods
# Failed to process CNEY: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CNSP" not found or invalid periods
# Failed to process CNSP: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SYTA" not found or invalid periods
# Failed to process SYTA: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "GRI" not found or invalid periods
# Failed to process GRI: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "QNRX" not found or invalid periods
# Failed to process QNRX: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SPRC" not found or invalid periods
# Failed to process SPRC: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SXTC" not found or invalid periods
# Failed to process SXTC: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CBRGU" not found or invalid periods
# Failed to process CBRGU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SMFL" not found or invalid periods
# Failed to process SMFL: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "FRMEP" not found or invalid periods
# Failed to process FRMEP: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BHFAL" not found or invalid periods
# Failed to process BHFAL: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "OPINL" not found or invalid periods
# Failed to process OPINL: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SPWRV" not found or invalid periods
# Failed to process SPWRV: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "MAXNV" not found or invalid periods
# Failed to process MAXNV: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "MCACR" not found or invalid periods
# Failed to process MCACR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SPEL" not found or invalid periods
# Failed to process SPEL: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "MVNR" not found or invalid periods
# Failed to process MVNR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BREZR" not found or invalid periods
# Failed to process BREZR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "HROWL" not found or invalid periods
# Failed to process HROWL: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "RILYK" not found or invalid periods
# Failed to process RILYK: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SNCRL" not found or invalid periods
# Failed to process SNCRL: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "METCL" not found or invalid periods
# Failed to process METCL: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "RILYZ" not found or invalid periods
# Failed to process RILYZ: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "IMAQR" not found or invalid periods
# Failed to process IMAQR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "WHLRL" not found or invalid periods
# Failed to process WHLRL: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CLOER" not found or invalid periods
# Failed to process CLOER: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "NOVVR" not found or invalid periods
# Failed to process NOVVR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "WINVR" not found or invalid periods
# Failed to process WINVR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "GREEL" not found or invalid periods
# Failed to process GREEL: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BNIXR" not found or invalid periods
# Failed to process BNIXR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ARBKL" not found or invalid periods
# Failed to process ARBKL: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "FOSLL" not found or invalid periods
# Failed to process FOSLL: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "HHGCR" not found or invalid periods
# Failed to process HHGCR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ATLCL" not found or invalid periods
# Failed to process ATLCL: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "MCAGR" not found or invalid periods
# Failed to process MCAGR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "RILYG" not found or invalid periods
# Failed to process RILYG: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "GLLIR" not found or invalid periods
# Failed to process GLLIR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BLEUR" not found or invalid periods
# Failed to process BLEUR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "FEXDR" not found or invalid periods
# Failed to process FEXDR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ALSAR" not found or invalid periods
# Failed to process ALSAR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "IGTAR" not found or invalid periods
# Failed to process IGTAR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "WTMAR" not found or invalid periods
# Failed to process WTMAR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "KACLR" not found or invalid periods
# Failed to process KACLR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "NVACR" not found or invalid periods
# Failed to process NVACR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BRACR" not found or invalid periods
# Failed to process BRACR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CSLMR" not found or invalid periods
# Failed to process CSLMR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BWAQR" not found or invalid periods
# Failed to process BWAQR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "GDSTR" not found or invalid periods
# Failed to process GDSTR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "RFACR" not found or invalid periods
# Failed to process RFACR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ASCBR" not found or invalid periods
# Failed to process ASCBR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "MSSAR" not found or invalid periods
# Failed to process MSSAR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "RWODR" not found or invalid periods
# Failed to process RWODR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CLRCR" not found or invalid periods
# Failed to process CLRCR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "GBBKR" not found or invalid periods
# Failed to process GBBKR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "YOTAR" not found or invalid periods
# Failed to process YOTAR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "FLFVR" not found or invalid periods
# Failed to process FLFVR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "EMCGR" not found or invalid periods
# Failed to process EMCGR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "AQUNR" not found or invalid periods
# Failed to process AQUNR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SVIIR" not found or invalid periods
# Failed to process SVIIR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "GLSTR" not found or invalid periods
# Failed to process GLSTR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "QOMOR" not found or invalid periods
# Failed to process QOMOR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "TENKR" not found or invalid periods
# Failed to process TENKR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "HUDAR" not found or invalid periods
# Failed to process HUDAR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "HROWM" not found or invalid periods
# Failed to process HROWM: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "PLTNR" not found or invalid periods
# Failed to process PLTNR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ATMCR" not found or invalid periods
# Failed to process ATMCR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ATMVR" not found or invalid periods
# Failed to process ATMVR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "HSPOR" not found or invalid periods
# Failed to process HSPOR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BLACR" not found or invalid periods
# Failed to process BLACR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "MARXR" not found or invalid periods
# Failed to process MARXR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "DISTR" not found or invalid periods
# Failed to process DISTR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "CETUR" not found or invalid periods
# Failed to process CETUR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "TMTCR" not found or invalid periods
# Failed to process TMTCR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "TBMCR" not found or invalid periods
# Failed to process TBMCR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "OAKUR" not found or invalid periods
# Failed to process OAKUR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "GODNR" not found or invalid periods
# Failed to process GODNR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ESHAR" not found or invalid periods
# Failed to process ESHAR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BOWNR" not found or invalid periods
# Failed to process BOWNR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BUJAR" not found or invalid periods
# Failed to process BUJAR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SWKHL" not found or invalid periods
# Failed to process SWKHL: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "NNAGR" not found or invalid periods
# Failed to process NNAGR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "GLACR" not found or invalid periods
# Failed to process GLACR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ABLLL" not found or invalid periods
# Failed to process ABLLL: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "QETAR" not found or invalid periods
# Failed to process QETAR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BAYAR" not found or invalid periods
# Failed to process BAYAR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "AITRR" not found or invalid periods
# Failed to process AITRR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "IBLUU" not found or invalid periods
# Failed to process IBLUU: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "AFJKR" not found or invalid periods
# Failed to process AFJKR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "PMNT" not found or invalid periods
# Failed to process PMNT: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "ATLCZ" not found or invalid periods
# Failed to process ATLCZ: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "IROHR" not found or invalid periods
# Failed to process IROHR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "JVSAR" not found or invalid periods
# Failed to process JVSAR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "DYCQR" not found or invalid periods
# Failed to process DYCQR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "IBACR" not found or invalid periods
# Failed to process IBACR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "BKHAR" not found or invalid periods
# Failed to process BKHAR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "NEWTG" not found or invalid periods
# Failed to process NEWTG: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "SIFYR" not found or invalid periods
# Failed to process SIFYR: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "WAY" not found or invalid periods
# Failed to process WAY: 'Close'
# HTTP Error 429: Too Many Requests  - symbol "RAPP" not found or invalid periods
# Failed to process RAPP: 'Close'

# %% [markdown]
# 필터링된 종목 데이터프레임 생성 및 정렬

# %%
filtered_stocks_df = pd.DataFrame(filtered_stocks_data)

# 거래량이 많고 변동폭이 낮은 순으로 정렬
filtered_stocks_df = filtered_stocks_df.sort_values(by=['Avg Volume', 'Volatility'], ascending=[False, True])

# 상위 10개 종목 선정
top_10_stocks_df = filtered_stocks_df.head(10)

# 결과 출력
print("조건에 맞는 상위 10개 종목 목록:")
print(top_10_stocks_df)
# Out:
# 조건에 맞는 상위 10개 종목 목록:
#    Symbol  Current Price  Recent Close    Trend    Buy Range  First Buy  \
# 2    SOFI           6.99          6.99  Uptrend  6.85 - 7.13     6.8502
# 0     WBD           8.27          8.27  Uptrend  8.10 - 8.44     8.1046
# 10   JBLU           5.56          5.56  Uptrend  5.45 - 5.67     5.4488
# 1    ERIC           6.22          6.22  Uptrend  6.10 - 6.34     6.0956
# 6    ASTS           8.62          8.62  Uptrend  8.45 - 8.79     8.4476
# 3    SMMT           7.72          7.72  Uptrend  7.57 - 7.87     7.5656
# 12   VIAV           7.40          7.40  Uptrend  7.25 - 7.55     7.2520
# 5     DLO           8.10          8.10  Uptrend  7.94 - 8.26     7.9380
# 4    GDRX           8.55          8.55  Uptrend  8.38 - 8.72     8.3790
# 14     LZ           8.41          8.41  Uptrend  8.24 - 8.58     8.2418
#
#     Second Buy  Third Buy  Take Profit  Stop Loss    Avg Volume  Volatility  \
# 2         6.99     7.1298        7.689     6.6405  4.359280e+07    1.304543
# 0         8.27     8.4354        9.097     7.8565  2.311970e+07    2.222927
# 10        5.56     5.6712        6.116     5.2820  1.371437e+07    1.343962
# 1         6.22     6.3444        6.842     5.9090  1.197217e+07    0.438418
# 6         8.62     8.7924        9.482     8.1890  3.541542e+06    1.372631
# 3         7.72     7.8744        8.492     7.3340  2.230660e+06    1.363717
# 12        7.40     7.5480        8.140     7.0300  1.893063e+06    1.190141
# 5         8.10     8.2620        8.910     7.6950  1.576551e+06    2.673477
# 4         8.55     8.7210        9.405     8.1225  1.563161e+06    0.921441
# 14        8.41     8.5782        9.251     7.9895  1.269549e+06    1.761326
#
#         Phase
# 2    Sleeping
# 0    Sleeping
# 10   Sleeping
# 1      Eating
# 6   Awakening
# 3      Eating
# 12   Sleeping
# 5    Sleeping
# 4      Eating
# 14   Sleeping

# %% [markdown]
# 필터링된 종목 리스트 데이터프레임 출력 함수

# %%
def display_dataframe_to_user(name: str, dataframe: pd.DataFrame) -> None:
    from IPython.display import display, HTML
    display(HTML(f"<h2>{name}</h2>"))
    display(dataframe)

display_dataframe_to_user(name="조건에 맞는 상위 10개 NASDAQ 종목 목록", dataframe=top_10_stocks_df)
# Out:
# <h2>조건에 맞는 상위 10개 NASDAQ 종목 목록</h2>
#    Symbol  Current Price  Recent Close    Trend    Buy Range  First Buy  \
# 2    SOFI           6.99          6.99  Uptrend  6.85 - 7.13     6.8502
# 0     WBD           8.27          8.27  Uptrend  8.10 - 8.44     8.1046
# 10   JBLU           5.56          5.56  Uptrend  5.45 - 5.67     5.4488
# 1    ERIC           6.22          6.22  Uptrend  6.10 - 6.34     6.0956
# 6    ASTS           8.62          8.62  Uptrend  8.45 - 8.79     8.4476
# 3    SMMT           7.72          7.72  Uptrend  7.57 - 7.87     7.5656
# 12   VIAV           7.40          7.40  Uptrend  7.25 - 7.55     7.2520
# 5     DLO           8.10          8.10  Uptrend  7.94 - 8.26     7.9380
# 4    GDRX           8.55          8.55  Uptrend  8.38 - 8.72     8.3790
# 14     LZ           8.41          8.41  Uptrend  8.24 - 8.58     8.2418
#
#     Second Buy  Third Buy  Take Profit  Stop Loss    Avg Volume  Volatility  \
# 2         6.99     7.1298        7.689     6.6405  4.359280e+07    1.304543
# 0         8.27     8.4354        9.097     7.8565  2.311970e+07    2.222927
# 10        5.56     5.6712        6.116     5.2820  1.371437e+07    1.343962
# 1         6.22     6.3444        6.842     5.9090  1.197217e+07    0.438418
# 6         8.62     8.7924        9.482     8.1890  3.541542e+06    1.372631
# 3         7.72     7.8744        8.492     7.3340  2.230660e+06    1.363717
# 12        7.40     7.5480        8.140     7.0300  1.893063e+06    1.190141
# 5         8.10     8.2620        8.910     7.6950  1.576551e+06    2.673477
# 4         8.55     8.7210        9.405     8.1225  1.563161e+06    0.921441
# 14        8.41     8.5782        9.251     7.9895  1.269549e+06    1.761326
#
#         Phase
# 2    Sleeping
# 0    Sleeping
# 10   Sleeping
# 1      Eating
# 6   Awakening
# 3      Eating
# 12   Sleeping
# 5    Sleeping
# 4      Eating
# 14   Sleeping
